# %% [markdown]
# <a href="https://colab.research.google.com/github/bijondev/-Google-Places-SDK-for-Android-AutoComplete/blob/main/pathao_app_food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
import requests

# %%
url = "https://api.pathao.com/v2/auth/country"

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-969635af5b09> in <cell line: 12>()
#      10 }
#      11
# ---> 12 response = requests.get(url, headers=headers)
#      13
#      14 print(response.text)
#
# NameError: name 'requests' is not defined

# %%
url = "https://api.pathao.com/v2/auth/register"

payload = "{\"country_prefix\":\"880\",\"national_number\":\"1911015506\",\"country_id\":1}"
headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "content-type": "application/json; charset=UTF-8",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.post(url, data=payload, headers=headers)

print(response.text)
# Out:
# {"message":"Message sent","retry_after":60,"token":"6455816da08407c75b8e7340a236b8512a95ae2023c74e0e1902bbd54c7fb043"}

# %%
url = "https://api.pathao.com/v2/auth/verify"

payload = "{\"country_prefix\":\"880\",\"national_number\":\"1911015506\",\"country_id\":1,\"code\":\"941641\",\"token\":\"6455816da08407c75b8e7340a236b8512a95ae2023c74e0e1902bbd54c7fb043\"}"
headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "content-type": "application/json; charset=UTF-8",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.post(url, data=payload, headers=headers)

print(response.text)
# Out:
# {"access_token":{"access_token":"lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM","token_type":"Bearer","expires_in":1706422564},"user":{"uuid":"86d26b45a9c111e7a36742010a8c0008","name":"bijon krishna bairagi","email":"01911015506@pathao.com","number":"01911015506","profile_pic":"/uploads/img/profile/fix_001_b705f5eb5e77203e2ebb273898c71c33e2230c103fcd8e1c206ca6e183c988ef.png","type":"user","welcome_back":false,"alt_number":"","address":"","gender":1,"date_of_birth":"1988-08-13","is_valid_date_of_birth":true,"needs_to_read_tos":0,"alternate_email":"bijon.bairgi@gmail.com","first_known_city_id":1,"last_known_city_id":1,"first_known_country_id":1,"last_known_country_id":1,"is_email_verified":0,"city":"Dhaka","city_id":1,"is_suspended":false,"wallet_id":"","wallet_is_active":false,"timezone":"Asia/Dhaka","is_social_sync":false,"is_social_active":false,"currency":"BDT","created":1492743546000,"updated":1522096773000,"deleted":0}}

# %%
url = "https://api.pathao.com/v1/is_service_available"

querystring = {
    "check": "food",
    "city_id": "1"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"success":true}

# %%
url = "https://api.pathao.com/v2/gmaps/geocode/23.79367/90.4066067"

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"address":"Kamal Ataturk, Banani","place_id":244189273529,"source":"pathao","short_address":{"bn":"বনানী কে ব্লক, বনানী","en":"Banani K Block, Banani"}}

# %%
response = requests.post(url, data=payload, headers=headers)

print(response.text)







import requests

url = "https://api.pathao.com/v1/foods/v2/cuisines/filters-and-cuisine"

querystring = {
    "cuisines": "1",
    "cuisine_top": "10",
    "group_filters": "1",
    "flat_filters": "1"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"Method Not Allowed"}
#
# ...

# %%
url = "https://api.pathao.com/v1/me/foods/v1/home"

querystring = { "city_id": "1" }

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# [{"api":"v1/me/foods/promo-label","serial_no":1,"type":"promo_label"},{"api":"v1/foods/v2/collections","auto_scroll":false,"serial_no":2,"type":"collection_name_list"},{"api":"v1/foods/v4/collections/f0609b85-6f6f-4509-8e73-297f6c4f5163","auto_scroll":true,"banner":"","collection_id":"f0609b85-6f6f-4509-8e73-297f6c4f5163","default_page_size":10,"icon":"","least_needed_count":1,"name":{"bn":"পিকস ফর ইউ 👌","en":"Picks For You 👌","ne":"तपाइँको लागी छनौट गर्दछ 👌"},"row_count":1,"see_all":{"text":{"bn":"সবগুলো দেখুন","en":"See All","ne":" सबै हेर"}},"serial_no":3,"type":"collection_view"},{"api":"v1/foods/v3/platform-screen","auto_scroll":true,"banner":"","collection_id":"12c09400-6aa9-43cd-b4d0-a66bfeb977d8","default_page_size":10,"icon":"http://storage.pathaofood.live/food/icon_featured.png?ts=1664172527","least_needed_count":1,"name":{"bn":"ফিচার্ড রেস্টুরেন্টস 🎉","en":"Featured Restaurants 🎉","ne":"चित्रित भोजनालय 🎉"},"row_count":2,"see_all":{"text":{"bn":"সবগুলো দেখুন","en":"See All"
# ...

# %%
url = "https://api.pathao.com/v1/foods/v4/search/restaurants"

querystring = {
    "exclude_pharma": "true",
    "city": "1",
    "lon": "90.4066067",
    "page": "1",
    "exclude_tong": "true",
    "lat": "23.79367",
    "page_size": "10"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer lYTczkZHHCfCmsCZtcOvPWXSRxEJUXirGVjXxLaM",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 540, "page_size": 10, "next": 2, "previous": null, "results": [{"id": "eea4e3db-11d4-4005-b25d-e6f03973fb5f", "is_open_now": true, "cuisines": [{"id": "5aa1a680-942e-4330-8c75-e36ea2c11081", "name": "Sweets"}], "business_hours": {"opening_time": "9:00:00", "closing_time": "22:00:00"}, "name": "Bhagyakul Mistanna Bhander - Banani", "address": "46/4, Kamal Ataturk Avenue, Banani.", "latitude": 23.793674, "longitude": 90.406639, "logo": null, "min_delivery_time": "60 min", "min_order_value": 50, "min_delivery_fee": 60, "discount_type": "PERCENTAGE", "discount": 0, "visible_in_app": true, "is_flagged": false, "score": 2085, "es_score": 41.058086, "banner": "http://storage.pathaofood.live/food/2547_banner.jpeg?t=1639292767", "opens_in": 0, "average_rating": 4.66, "rating": {"average_rating_str": "4.7", "average_rating_color": "#182229"}, "rating_count": null, "rating_count_str": "315", "free_delivery": false, "delivery_fee": 60, "discounted_delivery_fee": 30.0, "badges": ["20% C
# ...

# %%
url = "https://api.pathao.com/v1/foods/v4/search/restaurants"

querystring = {
    "exclude_pharma": "true",
    "city": "1",
    "lon": "90.4066067",
    "page": "1",
    "exclude_tong": "true",
    "lat": "23.79367",
    "page_size": "10"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 540, "page_size": 10, "next": 2, "previous": null, "results": [{"id": "eea4e3db-11d4-4005-b25d-e6f03973fb5f", "is_open_now": true, "cuisines": [{"id": "5aa1a680-942e-4330-8c75-e36ea2c11081", "name": "Sweets"}], "business_hours": {"opening_time": "9:00:00", "closing_time": "22:00:00"}, "name": "Bhagyakul Mistanna Bhander - Banani", "address": "46/4, Kamal Ataturk Avenue, Banani.", "latitude": 23.793674, "longitude": 90.406639, "logo": null, "min_delivery_time": "60 min", "min_order_value": 50, "min_delivery_fee": 60, "discount_type": "PERCENTAGE", "discount": 0, "visible_in_app": true, "is_flagged": false, "score": 2085, "es_score": 41.05808, "banner": "http://storage.pathaofood.live/food/2547_banner.jpeg?t=1639292767", "opens_in": 0, "average_rating": 4.66, "rating": {"average_rating_str": "4.7", "average_rating_color": "#182229"}, "rating_count": null, "rating_count_str": "315", "free_delivery": false, "delivery_fee": 60, "discounted_delivery_fee": 30.0, "badges": ["20% CA
# ...

# %%
url = "https://api.pathao.com/v1/foods/v4/collections/eea4e3db-11d4-4005-b25d-e6f03973fb5f"

querystring = {
    "lon": "90.4066067",
    "page": "1",
    "lat": "23.79367",
    "page_size": "10"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 0, "page_size": 10, "next": null, "previous": null, "results": []}

# %%
url = "https://api.pathao.com/v1/foods/v2/collections"

querystring = {
    "lat": "23.79367",
    "lon": "90.4066067"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 8, "next": null, "previous": null, "page_size": 8, "results": [{"cover": "https://storage.pathaofood.live/food/col_cover_foodie.jpg?ts=1672652356", "priority": 1, "id": "fffaf817-81dc-44c3-80a8-8389d61aeeda", "banner": "https://storage.pathaofood.live/food/col_banner_foodie.jpg?ts=1672652356", "icon": null, "name": "Foodie Me"}, {"cover": "https://storage.pathaofood.live/food/col_cover_hotcup.jpg?ts=1673175709", "priority": 4, "id": "8f071145-57a7-400f-adf0-d33f1f847e16", "banner": "https://storage.pathaofood.live/food/col_banner_hc.jpg?ts=1672746437", "icon": null, "name": "Hot Cup"}, {"cover": "http://storage.pathaofood.live/food/col_cover_jossdeals.jpg?ts=1666244666", "priority": 9, "id": "bdbc3a17-72c9-4201-9522-e9eff2b99bc9", "banner": "http://storage.pathaofood.live/food/col_banner_jossdeals.jpg?ts=1666244665", "icon": null, "name": "Joss Deals"}, {"cover": "http://storage.pathaofood.live/food/col_cover_09.%20Tong.png", "priority": 10, "id": "8ae90021-7859-4e16-b2bf-d
# ...

# %%
url = "https://api.pathao.com/v1/foods/v4/collections/563169bf-b37c-48a8-9be7-b08faf1f321a"

querystring = {
    "lon": "90.4066067",
    "page": "1",
    "lat": "23.79367",
    "page_size": "10"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 31, "page_size": 10, "next": 2, "previous": null, "results": [{"id": "a42af57b-ea51-4494-b907-6669016832c0", "is_open_now": true, "cuisines": [{"id": "bd0c74f2-4d2b-48b0-af87-020cb84d9e7d", "name": "Salad"}, {"id": "8e2a0033-5ce9-48d7-b584-d1b0475486fb", "name": "Rolls-Wrap"}, {"id": "1bf8e776-7efb-441e-bc23-2131c1065581", "name": "Drinks And Beverages"}], "business_hours": {"opening_time": "11:00:00", "closing_time": "22:00:00"}, "name": "Peyala Cafe Gulshan Avenue", "address": "Plot -1/A, Road-49, Kamal Ataturk Avenue (Gulshan 2)", "latitude": 23.793276, "longitude": 90.410301, "logo": "http://storage.pathaofood.live/food/7311_logo.jpg", "min_delivery_time": "60 min", "min_order_value": 50, "min_delivery_fee": 60, "discount_type": "PERCENTAGE", "discount": 0, "visible_in_app": true, "is_flagged": false, "score": 23033, "banner": "http://storage.pathaofood.live/food/7311_banner.jpg", "opens_in": 0, "average_rating": 4.63, "rating": {"average_rating_str": "4.6", "average_ra
# ...

# %% [markdown]
# # **Restaurents Offer**

# %%
url = "https://api.pathao.com/v1/me/foods/restaurants/restaurant-offers"

querystring = {
    "city": "1",
    "lon": "90.4066067",
    "page": "2",
    "lat": "23.79367",
    "page_size": "1000"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count":19,"page_size":1000,"next":null,"previous":null,"results":[{"id":"2a2b20d1-9c9f-4ec5-b88b-a657366b942f","restaurant_detail":{"name":"Empty app card"},"title":"Hot Cups Main","description":"","image":"http:\/\/storage.pathaofood.live\/food\/26341f9e-75e6-411a-b288-e2491e82e459.jpeg","priority":1,"restaurant":null,"deep_link":"pathao:\/\/food?collection-id=188f5ab6-992e-4f17-80bc-732509e2fe93&name=Hot Cup","offer_type":"general","tags":["4e1fb01e-1981-4839-be37-a0d203df0e59"],"created_at":"2023-01-08T06:04:21.921000+00:00","modified_at":"2023-01-08T06:04:35.263000+00:00","city_id":1},{"id":"6d7b9e42-c2d3-4653-90c4-1ed68495e402","restaurant_detail":{"name":"Empty app card"},"title":"20% Cashback on bKash Payment","description":"","image":"http:\/\/storage.pathaofood.live\/food\/1a1a83d9-8c46-4009-923d-f552fcf97865.jpeg","priority":1,"restaurant":null,"deep_link":"https:\/\/pathao.com\/bn\/blog\/bkash-campaign-food\/","offer_type":"general","tags":["859361d3-acb0-44b8-87f1-a1a0b
# ...

# %% [markdown]
# # **Restaurenr details**

# %%
url = "https://api.pathao.com/v1/me/foods/v2/restaurants/43acc884-adcd-48bd-b697-4da660fd5157"

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"id":"43acc884-adcd-48bd-b697-4da660fd5157","name":"Burger Xpress - Banani","address":"House-33, Road-17, Block-E , Banani Bazar","latitude":23.792917251586914,"longitude":90.40788269042969,"city":1,"logo":"http://storage.pathaofood.live/food/30776_logo.jpg","banner":"https://storage.pathaofood.live/food/30776_banner.jpeg?ts=1671448650","is_open_now":true,"is_resto":true,"accepting_orders":true,"business_hours":{"opening_time":"11:00:00","closing_time":"23:59:00"},"cuisines":[{"id":"b6a6e206-a0c2-4af2-908f-0996fb317e5c","name":"Mexican"},{"id":"f171b604-fb5f-4572-9f25-e09f6ec2f95f","name":"Burgers"}],"vat":0,"service_charge":0,"discount_type":"PERCENTAGE","discount":0,"min_order_value":50,"min_discount_order_amount":0,"max_discount_amount":null,"delivery_fee":60,"free_delivery":false,"discounted_delivery_fee":30,"rating_count":3862,"average_rating":4.55,"rating_count_str":"3500+","visible_in_app":true,"badges":["20% CASHBACK on bKash \u0026 Nagad","Buy 1 Get 1 Free"],"tags":["BOGO",
# ...

# %%
url = "https://api.pathao.com/v1/foods/v1/restaurants/43acc884-adcd-48bd-b697-4da660fd5157/popular-items"

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# [{"id":"f85b8beb-c60d-41b0-8b95-e21ddeff653c","name":"Chicken Burger","image":"http://storage.pathaofood.live/food/4d997896-510c-4250-9e22-b88f606be6f8.jpg?ts=1663141586","description":"","price":159,"final_price":133.56,"is_variable_price":false,"discount_type":"PERCENTAGE","discount":16,"discount_amount":25.44,"available_from":"11:00:00","available_to":"23:59:00","is_available_now":true,"has_addon":true},{"id":"57e52442-b846-46e0-ac26-0bf6d326756b","name":"Bbq Rice Bowl","image":"http://storage.pathaofood.live/food/944fd16e-360e-4db1-a52b-d7616b710c15.jpg?ts=1663141586","description":"","price":189,"final_price":158.76,"is_variable_price":false,"discount_type":"PERCENTAGE","discount":16,"discount_amount":30.24,"available_from":"11:00:00","available_to":"23:59:00","is_available_now":true,"has_addon":false},{"id":"f29f2b4e-e5a2-472c-9952-1047f7ee09e0","name":"Potato Wedges","image":"http://storage.pathaofood.live/food/8b6deb09-cc43-471c-91b8-b0a3813e675b.jpg?ts=1663141586","descripti
# ...

# %%
url = "https://api.pathao.com/v1/me/foods/promo-label"

querystring = {
    "city_id": "1",
    "restaurant_id": "43acc884-adcd-48bd-b697-4da660fd5157",
    "lat": "23.79367",
    "lon": "90.4066067"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"messages":["Use code FOODIE23 to get 20% off on orders over BDT 300"]}

# %% [markdown]
# # **Serach restaurent **

# %%
url = "https://api.pathao.com/v1/foods/v4/search/restaurants"

querystring = {
    "exclude_pharma": "true",
    "city": "1",
    "lon": "90.4066067",
    "page": "1",
    "exclude_tong": "true",
    "sort": "1",
    "lat": "23.79367",
    "page_size": "1000"
}

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count": 540, "page_size": 1000, "next": null, "previous": null, "results": [{"id": "eea4e3db-11d4-4005-b25d-e6f03973fb5f", "is_open_now": true, "cuisines": [{"id": "5aa1a680-942e-4330-8c75-e36ea2c11081", "name": "Sweets"}], "business_hours": {"opening_time": "9:00:00", "closing_time": "22:00:00"}, "name": "Bhagyakul Mistanna Bhander - Banani", "address": "46/4, Kamal Ataturk Avenue, Banani.", "latitude": 23.793674, "longitude": 90.406639, "logo": null, "min_delivery_time": "60 min", "min_order_value": 50, "min_delivery_fee": 60, "discount_type": "PERCENTAGE", "discount": 0, "visible_in_app": true, "is_flagged": false, "score": 2085, "es_score": 41.05151, "banner": "http://storage.pathaofood.live/food/2547_banner.jpeg?t=1639292767", "opens_in": 0, "average_rating": 4.66, "rating": {"average_rating_str": "4.7", "average_rating_color": "#182229"}, "rating_count": null, "rating_count_str": "315", "free_delivery": false, "delivery_fee": 60, "discounted_delivery_fee": 30.0, "badges": ["2
# ...

# %%
import requests

url = "https://api.pathao.com/v1/me/foods/v2/restaurants/25c68e9d-55fc-4d2c-bae6-475664dd2fc1/items"

headers = {
    "app-agent": "ride/android/413",
    "android-os": "13",
    "authorization": "Bearer SVHolUnahohxAYytAmGwPxtIEZCTsoPwpdMyDWxQ",
    "city-id": "1",
    "country-id": "1",
    "host": "api.pathao.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip",
    "user-agent": "okhttp/3.14.9"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# [{"category":"Starter","details":{"name":"Starter","icon":null},"items":[{"id":"9f69b447-e8f7-497f-a72e-3deb487add93","category":{"name":"Starter"},"name":"Chicken Honey Wings","image":null,"priority":null,"description":"","price":220,"final_price":187,"is_variable_price":false,"discount_type":"PERCENTAGE","discount":15,"discount_amount":33,"available_from":"12:00:00","available_to":"23:50:00","is_available_now":true,"has_addon":false,"addon_counter":null,"is_visible":true,"is_deleted":false},{"id":"e748533e-fa9f-4473-b29f-c8d95d732e92","category":{"name":"Starter"},"name":"Chicken Tikka Egg Roll","image":null,"priority":null,"description":"","price":199,"final_price":169.15,"is_variable_price":false,"discount_type":"PERCENTAGE","discount":15,"discount_amount":29.85,"available_from":"12:00:00","available_to":"23:50:00","is_available_now":true,"has_addon":false,"addon_counter":null,"is_visible":true,"is_deleted":false},{"id":"52f77cda-fe79-41b4-8b7c-3e8e399a9289","category":{"name":"S
# ...
